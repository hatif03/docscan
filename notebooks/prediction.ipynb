# %%
import numpy as np 
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation = '!#$%&\'()*+:;<=>?[\\]^`{|}~'
    tableWhitespace = str.maketrans('', '', whitespace)
    tablePunctuation = str.maketrans('', '', punctuation)
    text = str(txt)
    text = text.lower()
    removeWhitespace = text.translate(tableWhitespace)
    removePunctuation = removeWhitespace.translate(tablePunctuation)

    return str(removePunctuation)

# %%
# load NER model
model_ner = spacy.load('../models/output3/model-best/')

# %%
# Load Image
image = cv2.imread('./6.jpg')

#cv2.imshow('businesscard', image)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

#extract data using Pytesseract
tessData = pytesseract.image_to_data(image)

#convert into dataframe
tessList = list(map(lambda x:x.split('\t'), tessData.split('\n')))
df = pd.DataFrame (tessList [1:], columns=tessList[0])
df.dropna(inplace=True) # drop missing values
df['text'] = df['text'].apply(cleanText)


# convet data into content
df_clean = df.query('text != "" ')
content= " ".join([w for w in df_clean['text']])
print(content)

# get prediction from NER model
doc = model_ner(content)
# Out:
# cell 8099948528 ga 8466045457 email lictsrikant@gmail.com life insurance corporation of india seosrika ntht@gmail “com thathineni srikanth insurance advisor agent code no. 0316164y life insurance corporation of india br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018. lictsrikant8099948528.blogspot.in, interviewsinhyderabad.blogspot.in facebook.com/lictsrikant8099948528, facebook.com/thathineni.srikanth.9 promote your business online pybo

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528 ga 8466045457 email
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  india seosrika ntht@gmail
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     “
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     com thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     agent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     code
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0316164y life insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     br.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     off.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lic office,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     trimulgherry,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sec’bad - 500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     016.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     add.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     borabanda, hyderabad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHO

# %% [markdown]
# ## Tagging

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
doc_text = docjson['text']

# %%
datafram_tokens = pd.DataFrame(docjson['tokens'])
datafram_tokens['token'] = datafram_tokens [['start','end']].apply( 
    lambda x:doc_text[x[0]:x[1]], axis = 1)
datafram_tokens.head(10)
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\2531409549.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x:doc_text[x[0]:x[1]], axis = 1)
#    id  start  end                  token
# 0   0      0    4                   cell
# 1   1      5   15             8099948528
# 2   2     16   18                     ga
# 3   3     19   29             8466045457
# 4   4     30   35                  email
# 5   5     36   57  lictsrikant@gmail.com
# 6   6     58   62                   life
# 7   7     63   72              insurance
# 8   8     73   84            corporation
# 9   9     85   87                     of

# %%
right_table = pd.DataFrame(docjson['ents']) [['start', 'label']]
datafram_tokens = pd.merge(datafram_tokens, right_table, how='left',on='start')

# %%
datafram_tokens.fillna('O',inplace=True)
datafram_tokens.head(10)
# Out:
#    id  start  end                  token    label
# 0   0      0    4                   cell        O
# 1   1      5   15             8099948528  B-PHONE
# 2   2     16   18                     ga        O
# 3   3     19   29             8466045457        O
# 4   4     30   35                  email        O
# 5   5     36   57  lictsrikant@gmail.com  B-EMAIL
# 6   6     58   62                   life    I-ORG
# 7   7     63   72              insurance    I-ORG
# 8   8     73   84            corporation    I-ORG
# 9   9     85   87                     of    I-ORG

# %%
# join lable to df_clean dataframe
df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() - 1 
df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\1286819257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() - 1
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\1286819257.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\1286819257.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)

# %%
# inner join with start 
dataframe_info = pd.merge(df_clean,datafram_tokens[['start','token','label']],how='inner',on='start')

# %%
dataframe_info.tail(10)
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 41     5        1         6       3        1        6  495  474    53     21
# 42     5        1         6       3        2        1   46  506   430     27
# 43     5        1         6       3        2        2  488  506   429     27
# 44     5        1         6       3        3        1   44  539   472     25
# 45     5        1         6       3        3        2  526  539   443     22
# 46     5        1         6       3        4        1   46  571   106     21
# 47     5        1         6       3        4        2  161  576    56     22
# 48     5        1         6       3        4        3  226  571   111     21
# 49     5        1         6       3        4        4  347  571    74     21
# 50     5        1         6       3        4        5  432  571    96     27
#
#          conf                                 text  end  start  \
# 41  96.027008                                 018.  307    303
# 42  85.618164   lictsrikant8099948528.blogspot.in,  342    308
# 43  89.912384    interviewsinhyderabad.blogspot.in  376    343
# 44  87.967415  facebook.com/lictsrikant8099948528,  412    377
# 45  90.545654   facebook.com/thathineni.srikanth.9  447    413
# 46  96.344551                              promote  455    448
# 47  95.835091                                 your  460    456
# 48  96.409111                             business  469    461
# 49  93.162605                               online  476    470
# 50  92.261208                                 pybo  481    477
#
#                                  token    label
# 41                                 018    I-ORG
# 42   lictsrikant8099948528.blogspot.in  B-PHONE
# 43   interviewsinhyderabad.blogspot.in        O
# 44  facebook.com/lictsrikant8099948528  B-PHONE
# 45  facebook.com/thathineni.srikanth.9        O
# 46                             promote    I-ORG
# 47                                your    I-ORG
# 48                            business    I-ORG
# 49                              online    I-ORG
# 50                                pybo        O

# %% [markdown]
# ## Bounding Box

# %%
bb_df = dataframe_info.query("label != 'O' ")
img = image.copy()

for x,y,w,h,label in bb_df[['left','top','width','height','label']].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.putText(img,str(label),(x,y),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255),2)
    
    
cv2.imshow('Predictions',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
bb_df.head()
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\2854881843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
#   level page_num block_num par_num line_num word_num left  top width height  \
# 1     5        1         3       1        1        3  822   53   203     28
# 5     5        1         3       2        2        3  709  136   316     31
# 6     5        1         3       3        1        1   46  170    33     14
# 7     5        1         3       3        1        2   85  151    92     42
# 8     5        1         3       3        1        3  183  170   117     14
#
#         conf                   text  end  start                  token  label
# 1  96.483879             8099948528   15      5             8099948528  PHONE
# 5  86.249245  lictsrikant@gmail.com   57     36  lictsrikant@gmail.com  EMAIL
# 6  96.406654                   life   62     58                   life    ORG
# 7  95.806709              insurance   72     63              insurance    ORG
# 8  96.909729            corporation   84     73            corporation    ORG

# %%
# group the label
class groupgen():
    def __init__(self):
        self.id = 0
        self.text = ''
        
    def getgroup(self,text):
        if self.text == text:
            return self.id
        else:
            self.id +=1
            self.text = text
            return self.id
        
grp_gen = groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\472836701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
# right and bottom of bounding box
bb_df[['left','top','width','height']] = bb_df[['left','top','width','height']].astype(int)
bb_df['right'] = bb_df['left'] + bb_df['width']
bb_df['bottom'] = bb_df['top'] + bb_df['height']
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\262737354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left','top','width','height']] = bb_df[['left','top','width','height']].astype(int)
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\262737354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\262737354.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
# tagging: groupby group
col_group = ['left','top','right','bottom','label','token','group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
img_tagging = group_tag_img.agg({
    
    'left':min,
    'right':max,
    'top':min,
    'bottom':max,
    'label':np.unique,
    'token':lambda x: " ".join(x)
    
})
# Out:
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\976584219.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   img_tagging = group_tag_img.agg({
# C:\Users\mdhat\AppData\Local\Temp\ipykernel_9384\976584219.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   img_tagging = group_tag_img.agg({

# %%
img_tagging
# Out:
#        left  right  top  bottom    label  \
# group
# 1       822   1025   53      81  [PHONE]
# 2       709   1025  136     167  [EMAIL]
# 3        46   1025  151     341    [ORG]
# 4       582    737  310     335  [PHONE]
# 5        45    882  395     463    [ORG]
# 6       149    191  441     463  [PHONE]
# 7       290    453  441     468    [ORG]
# 8       465    566  441     463  [PHONE]
# 9        44    703  441     495    [ORG]
# 10      118    262  474     499  [PHONE]
# 11      495    548  474     495    [ORG]
# 12       44    516  506     564  [PHONE]
# 13       46    421  571     598    [ORG]
#
#                                                    token
# group
# 1                                             8099948528
# 2                                  lictsrikant@gmail.com
# 3      life insurance corporation of “ srikanth insur...
# 4                                               0316164y
# 5                            corporation of india br off
# 6                                                    lic
# 7                                           trimulgherry
# 8                                                sec’bad
# 9                                                016 add
# 10                                             borabanda
# 11                                                   018
# 12     lictsrikant8099948528.blogspot.in facebook.com...
# 13                          promote your business online

# %%
img_bb = image.copy()
for l,r,t,b,label,token in img_tagging.values:
    cv2.rectangle(img_bb,(l,t),(r,b),(0,255,0),2)
    
    cv2.putText(img_bb,label,(l,t),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255),2)
    
    
cv2.imshow('Bounding Box BusinessCard',img_bb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 5
#       2 for l,r,t,b,label,token in img_tagging.values:
#       3     cv2.rectangle(img_bb,(l,t),(r,b),(0,255,0),2)
# ----> 5     cv2.putText(img_bb,label,(l,t),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255),2)
#       8 cv2.imshow('Bounding Box BusinessCard',img_bb)
#       9 cv2.waitKey(0)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'putText'
# > Overload resolution failed:
# >  - Can't convert object to 'str' for 'text'
# >  - Can't convert object to 'str' for 'text'

# %% [markdown]
# ## Parser

# %%
def parser(text,label):
    if label == 'PHONE':
        text = text.lower()
        text = re.sub(r'\D','',text)
        
    elif label == 'EMAIL':
        text = text.lower()
        allow_special_char = '@_.\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
        
    elif label == 'WEB':
        text = text.lower()
        allow_special_char = ':/.%#\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
        
    elif label in ('NAME', 'DES'):
        text = text.lower()
        text = re.sub(r'[^a-z ]','',text)
        text = text.title()
        
    elif label == 'ORG':
        text = text.lower()
        text = re.sub(r'[^a-z0-9 ]','',text)
        text = text.title()
        
    return text

# %% [markdown]
# ### Entities

# %%
info_array = dataframe_info[['token','label']].values
entities = dict(NAME=[],ORG=[],DES=[],PHONE=[],EMAIL=[],WEB=[])
previous = 'O'

for token, label in info_array:
    bio_tag = label[0]
    label_tag = label[2:]
    
    # step -1 parse the token
    text = parser(token,label_tag)
    
    if bio_tag in ('B','I'):
        
        if previous != label_tag:
            entities[label_tag].append(text)
            
        else:
            if bio_tag == "B":
                entities[label_tag].append(text)
                
            else:
                if label_tag in ("NAME",'ORG','DES'):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                    
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text
                    
    
    
    previous = label_tag

# %%
entities
# Out:
# {'NAME': [],
#  'ORG': ['Life Insurance Corporation Of',
#   '',
#   'Srikanth Insurance Advisor Agent Code No',
#   'Corporation Of India Br Off',
#   'Trimulgherry',
#   '016 Add',
#   '018',
#   'Promote Your Business Online'],
#  'DES': [],
#  'PHONE': ['8099948528', '0316164', '', '', '', '8099948528', '8099948528'],
#  'EMAIL': ['lictsrikant@gmail.com'],
#  'WEB': []}
